# %% [markdown]
# <a href="https://colab.research.google.com/github/lmcanavals/algorithmic_complexity/blob/main/notebooks/bb_disjointset_quick_find.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Disjoint sets

# %%
# !git clone https://github.com/lmcanavals/algorithmic_complexity.git
# Out:
# Cloning into 'algorithmic_complexity'...
# remote: Enumerating objects: 284, done.
# remote: Counting objects: 100% (284/284), done.
# remote: Compressing objects: 100% (279/279), done.
# remote: Total 284 (delta 161), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (284/284), 280.17 KiB | 5.72 MiB/s, done.
# Resolving deltas: 100% (161/161), done.

# %%
from algorithmic_complexity.aclib.ds import ds2gv

# %% [markdown]
# ## Quick union

# %%
class DisjointSet:
  def __init__(self, n):
    self.s = list(range(n))

  def find(self, e):
    return self.s[e]

  def union(self, a, b):
    A = self.find(a)
    B = self.find(b)
    if A != B:
      for e, parent in enumerate(self.s):
        if parent == B:
          self.s[e] = A

# %%
ds = DisjointSet(8)
print(ds.s)
print(ds.find(5))
print(ds.find(7))
ds2gv(ds)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]
# 5
# 7

# %%
ds.union(5, 7)
print(ds.s)
print(ds.find(5))
print(ds.find(7))
ds2gv(ds)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 5]
# 5
# 5

# %%
ds.union(2, 4)
print(ds.s)
ds2gv(ds)
# Out:
# [0, 1, 2, 3, 2, 5, 6, 5]

# %%
ds.union(4, 7)
print(ds.s)
ds2gv(ds)
# Out:
# [0, 1, 2, 3, 2, 2, 6, 2]

# %%
ds.union(3, 0)
print(ds.s)
ds2gv(ds)
# Out:
# [3, 1, 2, 3, 2, 2, 6, 2]

# %%
ds.union(2, 7)
print(ds.s)
ds2gv(ds)
# Out:
# [3, 1, 2, 3, 2, 2, 6, 2]

# %%
ds.union(1, 0)
print(ds.s)
ds2gv(ds)
# Out:
# [1, 1, 2, 1, 2, 2, 6, 2]

# %%
ds.union(3, 5)
print(ds.s)
ds2gv(ds)
# Out:
# [1, 1, 1, 1, 1, 1, 6, 1]

# %%
ds.union(6, 7)
print(ds.s)
ds2gv(ds)
# Out:
# [6, 6, 6, 6, 6, 6, 6, 6]

# %%
ds2 = DisjointSet(8)
for i in range(1, 8):
  ds2.union(i, 0)

ds2gv(ds2)
